# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Importing the dataset

# %%
import io 
# %cd "C:\Users\svs\Downloads\Python-Project"
# Out:
# C:\Users\svs\Downloads\Python-Project

# %% [markdown]
# # Reading the dataset

# %%
churn=pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
# Head() is the function we Prints the Starting 5 Rows Default
churn.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# Tail() is funcation we Print Last 5 Rows Default
churn.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
churn.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Checking for datatype mismatches

# %%
# Info() is a funaction it is used find the about whole Data in Table like Number of Rows, Numbers of Columns,
# DataTypes, Size of table...etc

churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
churn.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
churn.shape
# Out:
# (7043, 21)

# %% [markdown]
# ### Changing the datatypes that are mismatched

# %%
churn.TotalCharges=pd.to_numeric(churn.TotalCharges,errors='coerce')

# %%
churn.SeniorCitizen=churn.SeniorCitizen.astype('object')

# %%
churn.describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  7043.000000     7043.000000   7032.000000
# mean     32.371149       64.761692   2283.300441
# std      24.559481       30.090047   2266.771362
# min       0.000000       18.250000     18.800000
# 25%       9.000000       35.500000    401.450000
# 50%      29.000000       70.350000   1397.475000
# 75%      55.000000       89.850000   3794.737500
# max      72.000000      118.750000   8684.800000

# %% [markdown]
# ### Dropping unwanted variables

# %%
churn=churn.drop(["customerID"],axis=1)

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   object
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
churn.shape
# Out:
# (7043, 20)

# %% [markdown]
# ### Visualizinf the distribution of Data

# %%
# histogram, boxplot & density curve - MonthlyCharges 
plt.figure(figsize=(10,15))

plt.subplot(3,1,1)
plt.hist(churn.MonthlyCharges)
plt.title('Histogram of Monthly_charges')
plt.xlabel('Monthlycharges')
plt.ylabel('Frequency')

plt.subplot(3,1,2)
plt.boxplot(churn.MonthlyCharges,vert=False)
plt.title('Boxplot of Monthly_charges')
plt.xlabel('Monthlycharges')

plt.subplot(3,1,3)
sns.kdeplot(churn.MonthlyCharges)
plt.title('Density curve of Monthly_charges')
plt.xlabel('Monthlycharges')
# Out:
# Text(0.5, 0, 'Monthlycharges')

# %%
# histogram, boxplot & density curve - tenure
plt.figure(figsize=(12,10))

plt.subplot(2,2,1)
plt.hist(churn.tenure)
plt.title('Histogram of Tenure')
plt.xlabel('Tenure')
plt.ylabel('Frequency')

plt.subplot(2,2,2)
plt.boxplot(churn.tenure,vert=False)
plt.title('Boxplot of Tenure')
plt.xlabel('Tenure')

plt.subplot(2,2,3)
sns.kdeplot(churn.tenure)
plt.title('Density curve of Tenure')
plt.xlabel('Tenure')
# Out:
# Text(0.5, 0, 'Tenure')

# %% [markdown]
# ### Checking for missing values

# %%
churn.isnull().sum().sort_values(ascending=False)/churn.shape[0]
# Out:
# TotalCharges        0.001562
# gender              0.000000
# SeniorCitizen       0.000000
# MonthlyCharges      0.000000
# PaymentMethod       0.000000
# PaperlessBilling    0.000000
# Contract            0.000000
# StreamingMovies     0.000000
# StreamingTV         0.000000
# TechSupport         0.000000
# DeviceProtection    0.000000
# OnlineBackup        0.000000
# OnlineSecurity      0.000000
# InternetService     0.000000
# MultipleLines       0.000000
# PhoneService        0.000000
# tenure              0.000000
# Dependents          0.000000
# Partner             0.000000
# Churn               0.000000
# dtype: float64

# %% [markdown]
# ### Missing Values Imputation with median

# %%
churn.TotalCharges=churn.TotalCharges.fillna(churn.TotalCharges.median())
# Median imputation is preferred when the distribution is skewed, as the median is less sensitive to outliers than the mean.

# %%
churn.isnull().sum().sort_values(ascending=False)/churn.shape[0]
# Out:
# gender              0.0
# SeniorCitizen       0.0
# TotalCharges        0.0
# MonthlyCharges      0.0
# PaymentMethod       0.0
# PaperlessBilling    0.0
# Contract            0.0
# StreamingMovies     0.0
# StreamingTV         0.0
# TechSupport         0.0
# DeviceProtection    0.0
# OnlineBackup        0.0
# OnlineSecurity      0.0
# InternetService     0.0
# MultipleLines       0.0
# PhoneService        0.0
# tenure              0.0
# Dependents          0.0
# Partner             0.0
# Churn               0.0
# dtype: float64

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Frequency Counts -  To find the frequency of unique value in a Pandas series values_counts() function is used

# %%
# Frequency Counts of following variables
# Churn, gender, SeniorCitizen, PaymentMethod
a=churn[['Churn','gender', 'SeniorCitizen','PaymentMethod']]
for i in a.columns:
    freq=a[i].value_counts(dropna=False)
    print(freq)
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64
# Male      3555
# Female    3488
# Name: gender, dtype: int64
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %%
# Frequency Counts of the variable Churn
plt.figure(figsize=(15,10))
churn.Churn.value_counts().plot(kind='pie',autopct='%.1f%%',legend=True,colors=('red','yellow'))
plt.title('Frequncy Counts of Churn in %')
plt.legend(title='Churn',loc='best')

# %%
# Frequency Counts of the variable  gender
plt.figure(figsize=(15,10))
churn.gender.value_counts().plot(kind='pie',autopct='%.1f%%',legend=True,colors=('teal','cyan'))
plt.title('Frequncy Counts of Gender in %')
plt.legend(title='Gender',loc='best')

# %%
# Frequency Counts of the variable SeniorCitizen
plt.figure(figsize=(15,10))
churn.SeniorCitizen.value_counts().plot(kind='pie',autopct='%.1f%%',legend=True,
                                        colors=('skyblue','violet'))
plt.title('Frequncy Counts Senior Citizen in %')
plt.legend(title='Senior_Citizen',loc='best')

# %%
# Frequency Counts of the variable PaymentMethod
plt.figure(figsize=(15,10))
churn.PaymentMethod.value_counts().plot(kind='pie',autopct='%.1f%%',legend=True)
                                       
plt.title('Frequncy Counts of Payment Method in %')
plt.legend(title='Payment_Method',loc='best')

# %% [markdown]
# ###  Cross Tabulation - This function makes it so easy to get counts and percentages with totals.

# %%
# Cross Tabulation of Churn & gender
print(pd.crosstab(churn.Churn,churn.gender))
# Out:
# gender  Female  Male
# Churn
# No        2549  2625
# Yes        939   930

# %%
a=pd.crosstab(churn.Churn,churn.gender).plot(kind='bar',
                                             title='Cross Tabulation for Churn & Gender',stacked=True,figsize=(10,8),
                                             color=('silver','brown'))
for i in a.containers:
    a.bar_label(i,fontsize=10)
    plt.ylabel('Frequency')
    plt.xticks(rotation=0)

# %%
# Cross Tabulation of Churn & InternetService
print(pd.crosstab(churn.Churn,churn.InternetService))
# Out:
# InternetService   DSL  Fiber optic    No
# Churn
# No               1962         1799  1413
# Yes               459         1297   113

# %%
a=pd.crosstab(churn.Churn,churn.InternetService).plot(kind='bar',
                                             title='Cross Tabulation for Churn & Internet_Service',stacked=True,figsize=(10,8),
                                             color=('maroon','tan','olive'))
for i in a.containers:
    a.bar_label(i,fontsize=10)
    plt.ylabel('Frequency')
    plt.xticks(rotation=0)

# %%
# Cross Tabulation of Churn & SeniorCitizen
print(pd.crosstab(churn.Churn,churn.SeniorCitizen))
# Out:
# SeniorCitizen     0    1
# Churn
# No             4508  666
# Yes            1393  476

# %%
a=pd.crosstab(churn.Churn,churn.SeniorCitizen).plot(kind='bar',
                                             title='Cross Tabulation for Churn & Internet_Service',stacked=True,figsize=(10,8),
                                             color=('orange','green'))
for i in a.containers:
    a.bar_label(i,fontsize=10)
    plt.ylabel('Frequency')
    plt.xticks(rotation=0)

# %%
# Cross Tabulation of Churn & Partner
print(pd.crosstab(churn.Churn,churn.Partner))
# Out:
# Partner    No   Yes
# Churn
# No       2441  2733
# Yes      1200   669

# %%
a=pd.crosstab(churn.Churn,churn.Partner).plot(kind='bar',
                                             title='Cross Tabulation for Churn & Internet_Service',stacked=True,figsize=(10,8),
                                             color=('blue','red'))
for i in a.containers:
    a.bar_label(i,fontsize=10)
    plt.ylabel('Frequency')
    plt.xticks(rotation=0)

# %%
# Cross Tabulation of Churn & Dependents
print(pd.crosstab(churn.Churn,churn.Dependents))
# Out:
# Dependents    No   Yes
# Churn
# No          3390  1784
# Yes         1543   326

# %%
a=pd.crosstab(churn.Churn,churn.Partner).plot(kind='bar',
                                             title='Cross Tabulation for Churn & Internet_Service',stacked=True,figsize=(10,8))
                                             
for i in a.containers:
    a.bar_label(i,fontsize=10)
    plt.ylabel('Frequency')
    plt.xticks(rotation=0)

# %% [markdown]
# ### Groupby() - groupby() function is used to separate identical data into groups to allow for further aggregation and analysis

# %%
# Average MonthlyCharges by gender
print(churn.MonthlyCharges.groupby(churn.gender).mean())
plt.figure(figsize=(10,6))
a=round(churn.MonthlyCharges.groupby(churn.gender).mean(),1).plot(kind='bar',title='Average MonthlyCharges by gender')
for i in a.containers:
    a.bar_label(i,fontsize=10)
    plt.xticks(rotation=0)
    plt.xlabel('Gender')
    plt.ylabel('Average Monthly Charges')
# Out:
# gender
# Female    65.204243
# Male      64.327482
# Name: MonthlyCharges, dtype: float64

# %%
# Average tenure by SeniorCitizen
print(churn.tenure.groupby(churn.SeniorCitizen).mean())
plt.figure(figsize=(10,6))
a=round(churn.tenure.groupby(churn.SeniorCitizen).mean(),1).plot(kind='bar',title='Average Tenure by SeniorCitizen')
for i in a.containers:
    a.bar_label(i,fontsize=10)
    plt.xticks(rotation=0)
    plt.xlabel('Senior_Citizen')
    plt.ylabel('Average Tenure')
# Out:
# SeniorCitizen
# 0    32.192171
# 1    33.295972
# Name: tenure, dtype: float64

# %%
# Average tenure by PaymentMethod
print(churn.tenure.groupby(churn.PaymentMethod).mean())
plt.figure(figsize=(10,6))
a=round(churn.tenure.groupby(churn.PaymentMethod).mean(),1).plot(kind='bar',title='Average Tenure by Payment Method')
for i in a.containers:
    a.bar_label(i,fontsize=10)
    plt.xticks(rotation=0)
    plt.xlabel('Payment Method',fontsize=12)
    plt.ylabel('Average Tenure',fontsize=12)
# Out:
# PaymentMethod
# Bank transfer (automatic)    43.656736
# Credit card (automatic)      43.269382
# Electronic check             25.174630
# Mailed check                 21.830025
# Name: tenure, dtype: float64

# %%
# Average tenure by InternetService
print(churn.tenure.groupby(churn.InternetService).mean())
plt.figure(figsize=(10,6))
a=round(churn.tenure.groupby(churn.InternetService).mean(),1).plot(kind='bar',title='Average Tenure by Internet Service')
for i in a.containers:
    a.bar_label(i,fontsize=10)
    plt.xticks(rotation=0)
    plt.xlabel('Internet Service')
    plt.ylabel('Average Tenure')
# Out:
# InternetService
# DSL            32.821561
# Fiber optic    32.917959
# No             30.547182
# Name: tenure, dtype: float64

# %%
# Average Monthly Charges by StreamingMovies
print(churn.tenure.groupby(churn.StreamingMovies).mean())
plt.figure(figsize=(10,6))
a=round(churn.tenure.groupby(churn.StreamingMovies).mean(),1).plot(kind='bar',title='Average Tenure by Streaming Movies')
for i in a.containers:
    a.bar_label(i,fontsize=10)
    plt.xticks(rotation=0)
    plt.xlabel('Streaming Movies',fontsize=12)
    plt.ylabel('Average Tenure',fontsize=12)
# Out:
# StreamingMovies
# No                     24.712388
# No internet service    30.547182
# Yes                    41.197291
# Name: tenure, dtype: float64

# %% [markdown]
# # Hypothesis Testing

# %%
#Test Null Average MonthlyCharges Churn Yes/No Equal
churn.MonthlyCharges.groupby(churn.Churn).mean()
# Out:
# Churn
# No     61.265124
# Yes    74.441332
# Name: MonthlyCharges, dtype: float64

# %%
from scipy.stats import ttest_ind

# %%
# Split
cno=churn[churn.Churn=='No']
cyes=churn[churn.Churn=='Yes']

# %%
ttest_ind(cyes.MonthlyCharges,cno.MonthlyCharges,equal_var=False)
# Since pvalue=8.59244933154705e-73 is less than 0.05,Reject Null
# Out:
# Ttest_indResult(statistic=18.407526676414673, pvalue=8.59244933154705e-73)

# %%
#Test Null Average tenure of Churn Yes/No Equal
churn.tenure.groupby(churn.Churn).mean()
# Out:
# Churn
# No     37.569965
# Yes    17.979133
# Name: tenure, dtype: float64

# %%
ttest_ind(cyes.tenure,cno.tenure,equal_var=False)
# Since pvalue=1.1954945472607151e-232 is less than 0.05,Reject Null
# Out:
# Ttest_indResult(statistic=-34.823818696312976, pvalue=1.1954945472607151e-232)

# %%
#Test Null Average Monthly Charges of different PaymentMethod Equal
churn.MonthlyCharges.groupby(churn.PaymentMethod).mean()
# Out:
# PaymentMethod
# Bank transfer (automatic)    67.192649
# Credit card (automatic)      66.512385
# Electronic check             76.255814
# Mailed check                 43.917060
# Name: MonthlyCharges, dtype: float64

# %%
paybt=churn[churn.PaymentMethod=='Bank transfer (automatic)']
paycd=churn[churn.PaymentMethod=='Credit card (automatic)']
payec=churn[churn.PaymentMethod=='Electronic check']
paymc=churn[churn.PaymentMethod=='Mailed check']

# %%
from scipy.stats import f_oneway

# %%
f_oneway(paybt.MonthlyCharges,paycd.MonthlyCharges,payec.MonthlyCharges,paymc.MonthlyCharges)
# Since pvalue=1.1802197193575694e-267 is less than 0.05,Reject Null
# Out:
# F_onewayResult(statistic=450.3189918892516, pvalue=1.1802197193575694e-267)

# %%
#Test Null Average tenure of different PaymentMethod Equal
f_oneway(paybt.tenure,paycd.tenure,payec.tenure,paymc.tenure)
# Since pvalue=1.503848361277172e-265 is less than 0.05,Reject Null
# Out:
# F_onewayResult(statistic=446.4668862479716, pvalue=1.503848361277172e-265)

# %%
#Test Null No Asssociation between gender & Churn
from scipy.stats import chi2_contingency

# %%
chi2_contingency(pd.crosstab(churn.gender,churn.Churn))
# Since pvalue=0.48657873605618596 is less than 0.05,Reject Null
# Out:
# Chi2ContingencyResult(statistic=0.4840828822091383, pvalue=0.48657873605618596, dof=1, expected_freq=array([[2562.38989067,  925.61010933],
#        [2611.61010933,  943.38989067]]))

# %%
#Test Null No Association between SeniorCitizen & Churn 
pd.crosstab(churn.SeniorCitizen,churn.Churn)
# Out:
# Churn            No   Yes
# SeniorCitizen
# 0              4508  1393
# 1               666   476

# %%
chi2_contingency(pd.crosstab(churn.SeniorCitizen,churn.Churn))
# Since pvalue=1.510066805092378e-36 is less than 0.05,Reject Null
# Out:
# Chi2ContingencyResult(statistic=159.42630036838742, pvalue=1.510066805092378e-36, dof=1, expected_freq=array([[4335.05239245, 1565.94760755],
#        [ 838.94760755,  303.05239245]]))

# %% [markdown]
# # Splitting data into numeric and categorical variables

# %%
churn.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
objcols=churn[['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport','StreamingTV', 'StreamingMovies', 'Contract', 
        'PaperlessBilling','PaymentMethod','Churn']]

# %%
numcols=churn[['tenure','MonthlyCharges', 'TotalCharges']]

# %% [markdown]
# ### get_dummies for objcols

# %%
objcols_dummy=pd.get_dummies(objcols.drop('Churn',axis=1))
# Out:
# C:\Users\svs\AppData\Local\Temp\ipykernel_6164\413636350.py:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   objcols_dummy=pd.get_dummies(objcols.drop('Churn',axis=1))

# %% [markdown]
# ### LabelEncoding the data With Churn as Dependent Variable

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
objcols.Churn=le.fit_transform(objcols.Churn)
# Out:
# C:\Users\svs\AppData\Local\Temp\ipykernel_6164\781276248.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   objcols.Churn=le.fit_transform(objcols.Churn)

# %%
objcols.head(50)
# Out:
#     gender SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0   Female             0     Yes         No           No  No phone service
# 1     Male             0      No         No          Yes                No
# 2     Male             0      No         No          Yes                No
# 3     Male             0      No         No           No  No phone service
# 4   Female             0      No         No          Yes                No
# 5   Female             0      No         No          Yes               Yes
# 6     Male             0      No        Yes          Yes               Yes
# 7   Female             0      No         No           No  No phone service
# 8   Female             0     Yes         No          Yes               Yes
# 9     Male             0      No        Yes          Yes                No
# 10    Male             0     Yes        Yes          Yes                No
# ...

# %% [markdown]
# ## scaling for numcols

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
numcols=scaler.fit_transform(numcols)

# %%
numcols=pd.DataFrame(numcols,columns=['tenure','MonthlyCharges', 'TotalCharges'])

# %%
cleandf=pd.concat([numcols,objcols_dummy,objcols.Churn],axis=1)

# %%
cleandf.head()
# Out:
#      tenure  MonthlyCharges  TotalCharges  gender_Female  gender_Male  \
# 0 -1.277445       -1.160323     -0.994242              1            0
# 1  0.066327       -0.259629     -0.173244              0            1
# 2 -1.236724       -0.362660     -0.959674              0            1
# 3  0.514251       -0.746535     -0.194766              0            1
# 4 -1.236724        0.197365     -0.940470              1            0
#
#    SeniorCitizen_0  SeniorCitizen_1  Partner_No  Partner_Yes  Dependents_No  \
# 0                1                0           0            1              1
# 1                1                0           1            0              1
# 2                1                0           1            0              1
# 3                1                0           1            0              1
# 4                1                0           1            0              1
#
#    ...  Contract_Month-to-month  Contract_One year  Contract_Two year  \
# ...

# %%
X=cleandf.drop('Churn',axis=1)
y=cleandf.Churn

# %%
from imblearn.over_sampling import SMOTENC

# %%
X.shape
# Out:
# (7043, 46)

# %%
X.head()
# Out:
#      tenure  MonthlyCharges  TotalCharges  gender_Female  gender_Male  \
# 0 -1.277445       -1.160323     -0.994242              1            0
# 1  0.066327       -0.259629     -0.173244              0            1
# 2 -1.236724       -0.362660     -0.959674              0            1
# 3  0.514251       -0.746535     -0.194766              0            1
# 4 -1.236724        0.197365     -0.940470              1            0
#
#    SeniorCitizen_0  SeniorCitizen_1  Partner_No  Partner_Yes  Dependents_No  \
# 0                1                0           0            1              1
# 1                1                0           1            0              1
# 2                1                0           1            0              1
# 3                1                0           1            0              1
# 4                1                0           1            0              1
#
#    ...  StreamingMovies_Yes  Contract_Month-to-month  Contract_One year  \
# ...

# %%
smote=SMOTENC(categorical_features=list(range(0,45)),random_state=42)

# %%
X_smt,y_smt=smote.fit_resample(X,y)

# %%
y_smt=pd.DataFrame(y_smt)

# %%
y_smt.value_counts()
# Out:
# Churn
# 0        5174
# 1        5174
# dtype: int64

# %% [markdown]
# # Model Building

# %% [markdown]
# ## a) Logistic Regression

# %% [markdown]
# ### Logistic Regression is used when the classification problem is binary i.e, yes or no and true or false

# %%
from sklearn.linear_model import LogisticRegression

# %%
reg=LogisticRegression(max_iter=1000)

# %%
logitmodel=reg.fit(X_smt,y_smt)
# Out:
# C:\Users\svs\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
logitmodel.score(X_smt,y_smt)
# Out:
# 0.7975454194047159

# %%
logitpredict=logitmodel.predict(X_smt)

# %%
from sklearn.metrics import ConfusionMatrixDisplay,RocCurveDisplay,classification_report

# %%
ConfusionMatrixDisplay.from_predictions(y_smt,logitpredict)

# %%
RocCurveDisplay.from_predictions(y_smt,logitpredict)

# %%
print(classification_report(y_smt,logitpredict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.77      0.79      5174
#            1       0.78      0.82      0.80      5174
#
#     accuracy                           0.80     10348
#    macro avg       0.80      0.80      0.80     10348
# weighted avg       0.80      0.80      0.80     10348

# %%
np.round(logitmodel.predict_proba(X_smt),2)
# Out:
# array([[0.19, 0.81],
#        [0.92, 0.08],
#        [0.5 , 0.5 ],
#        ...,
#        [0.36, 0.64],
#        [0.53, 0.47],
#        [0.29, 0.71]])

# %%
pd.DataFrame(logitmodel.coef_,columns=X_smt.columns).T
# Out:
#                                                 0
# tenure                                  -0.995020
# MonthlyCharges                           0.015926
# TotalCharges                             0.064328
# gender_Female                            0.015914
# gender_Male                             -0.013381
# SeniorCitizen_0                          0.006619
# SeniorCitizen_1                         -0.004085
# Partner_No                              -0.028350
# Partner_Yes                              0.030883
# Dependents_No                            0.167592
# Dependents_Yes                          -0.165058
# PhoneService_No                          0.092935
# PhoneService_Yes                        -0.090402
# MultipleLines_No                        -0.206233
# MultipleLines_No phone service           0.092935
# MultipleLines_Yes                        0.115831
# InternetService_DSL                     -0.449423
# InternetService_Fiber optic              0.546558
# ...

# %% [markdown]
# # b) DecisionTree Classifier

# %% [markdown]
# ### Decision Tree builds a tree branches and each branch considered as if-else statement

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score

# %%
tree=DecisionTreeClassifier(max_depth=9)

# %%
treemodel=tree.fit(X_smt,y_smt)

# %%
treemodel.score(X_smt,y_smt)
# Out:
# 0.8536915345960572

# %%
treepred=treemodel.predict(X_smt)

# %%
print(classification_report(y_smt,treepred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.86      0.85      5174
#            1       0.86      0.85      0.85      5174
#
#     accuracy                           0.85     10348
#    macro avg       0.85      0.85      0.85     10348
# weighted avg       0.85      0.85      0.85     10348

# %%
ConfusionMatrixDisplay.from_predictions(y_smt,treepred)

# %%
RocCurveDisplay.from_predictions(y_smt,treepred)

# %%
cross_val_score(tree,X_smt,y_smt)
# Out:
# array([0.73816425, 0.75217391, 0.83381643, 0.85935234, 0.84823586])

# %%
np.mean([0.73816425, 0.75217391, 0.83381643, 0.85935234, 0.84823586])
# Out:
# 0.806348558

# %% [markdown]
# # C) GradientBoosting Classifer

# %% [markdown]
# ### This algorithm combine many weak learning models together to create a strong predictive model.

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gb=GradientBoostingClassifier(n_estimators=1000)

# %%
gbmodel=gb.fit(X_smt,y_smt)
# Out:
# C:\Users\svs\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
gbmodel.score(X_smt,y_smt)
# Out:
# 0.9175686122922304

# %%
gbpred=gbmodel.predict(X_smt)

# %%
print(classification_report(y_smt,gbpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.92      5174
#            1       0.91      0.92      0.92      5174
#
#     accuracy                           0.92     10348
#    macro avg       0.92      0.92      0.92     10348
# weighted avg       0.92      0.92      0.92     10348

# %%
RocCurveDisplay.from_predictions(y_smt,gbpred)

# %%
ConfusionMatrixDisplay.from_predictions(y_smt,gbpred)

# %%
cross_val_score(gb,X_smt,y_smt)
# Out:
# C:\Users\svs\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\svs\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\svs\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
np.mean([0.76618357, 0.77294686, 0.8826087 , 0.89076849, 0.89705172])
# Out:
# 0.8419118680000001

# %% [markdown]
# # d) Support Vector Classifier

# %% [markdown]
# ### Similar to decision tree and random forest, support vector machine can be used in both classification and regression, SVC (support vector classifier) is for classification problem.

# %%
from sklearn.svm import SVC

# %%
svcmodel=SVC().fit(X_smt,y_smt)
# Out:
# C:\Users\svs\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
svcmodel.score(X_smt,y_smt)
# Out:
# 0.8382296095863935

# %%
svcpred=svcmodel.predict(X_smt)

# %%
print(classification_report(y_smt,svcpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.81      0.83      5174
#            1       0.82      0.86      0.84      5174
#
#     accuracy                           0.84     10348
#    macro avg       0.84      0.84      0.84     10348
# weighted avg       0.84      0.84      0.84     10348

# %%
ConfusionMatrixDisplay.from_predictions(y_smt,svcpred)

# %%
RocCurveDisplay.from_predictions(y_smt,svcpred)

# %%
cross_val_score(SVC(),X_smt,y_smt)
# Out:
# C:\Users\svs\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\svs\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\svs\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
np.mean([0.77101449, 0.76328502, 0.82850242, 0.84775254, 0.84775254])
# Out:
# 0.811661402

# %% [markdown]
# ### CAT BOOST

# %%
from catboost import CatBoostClassifier

# %%
cat=CatBoostClassifier(iterations=1000, learning_rate=0.1, depth=5)

# %%
catmodel=cat.fit(X_smt,y_smt)
# Out:
# 0:	learn: 0.6436302	total: 10.7ms	remaining: 10.7s
# 1:	learn: 0.5991400	total: 21ms	remaining: 10.5s
# 2:	learn: 0.5628711	total: 35ms	remaining: 11.6s
# 3:	learn: 0.5365771	total: 47.2ms	remaining: 11.7s
# 4:	learn: 0.5152910	total: 55.2ms	remaining: 11s
# 5:	learn: 0.4970804	total: 65.8ms	remaining: 10.9s
# 6:	learn: 0.4846519	total: 75.4ms	remaining: 10.7s
# 7:	learn: 0.4735698	total: 83.6ms	remaining: 10.4s
# 8:	learn: 0.4596938	total: 94.5ms	remaining: 10.4s
# 9:	learn: 0.4502617	total: 107ms	remaining: 10.6s
# 10:	learn: 0.4428470	total: 116ms	remaining: 10.4s
# 11:	learn: 0.4377607	total: 124ms	remaining: 10.2s
# 12:	learn: 0.4324814	total: 133ms	remaining: 10.1s
# 13:	learn: 0.4270372	total: 141ms	remaining: 9.93s
# 14:	learn: 0.4236195	total: 149ms	remaining: 9.78s
# 15:	learn: 0.4195663	total: 159ms	remaining: 9.76s
# 16:	learn: 0.4164913	total: 167ms	remaining: 9.65s
# 17:	learn: 0.4131703	total: 175ms	remaining: 9.55s
# 18:	learn: 0.4091818	total: 183ms	remaining: 9.45s
# ...

# %%
catmodel.score(X_smt,y_smt)
# Out:
# 0.9403749516814843

# %%
cross_val_score(cat,X_smt,y_smt)
# Out:
# 0:	learn: 0.6261515	total: 19.2ms	remaining: 19.2s
# 1:	learn: 0.5816424	total: 34.9ms	remaining: 17.4s
# 2:	learn: 0.5492175	total: 49.1ms	remaining: 16.3s
# 3:	learn: 0.5238772	total: 64.1ms	remaining: 16s
# 4:	learn: 0.5000577	total: 79.9ms	remaining: 15.9s
# 5:	learn: 0.4827751	total: 92.3ms	remaining: 15.3s
# 6:	learn: 0.4697930	total: 103ms	remaining: 14.7s
# 7:	learn: 0.4562903	total: 116ms	remaining: 14.3s
# 8:	learn: 0.4437617	total: 130ms	remaining: 14.3s
# 9:	learn: 0.4350912	total: 144ms	remaining: 14.2s
# 10:	learn: 0.4259655	total: 156ms	remaining: 14s
# 11:	learn: 0.4205604	total: 168ms	remaining: 13.8s
# 12:	learn: 0.4150624	total: 184ms	remaining: 13.9s
# 13:	learn: 0.4093287	total: 198ms	remaining: 14s
# 14:	learn: 0.4024482	total: 216ms	remaining: 14.2s
# 15:	learn: 0.3970413	total: 231ms	remaining: 14.2s
# 16:	learn: 0.3931602	total: 251ms	remaining: 14.5s
# 17:	learn: 0.3900525	total: 267ms	remaining: 14.5s
# 18:	learn: 0.3880466	total: 280ms	remaining: 14.4s
# ...

# %%
np.mean([0.75555556, 0.75507246, 0.8884058 , 0.89318511, 0.90430159])
# Out:
# 0.839304104

# %%
catpred=catmodel.predict(X_smt)

# %%
print(classification_report(y_smt,catpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      5174
#            1       0.94      0.95      0.94      5174
#
#     accuracy                           0.94     10348
#    macro avg       0.94      0.94      0.94     10348
# weighted avg       0.94      0.94      0.94     10348

# %%
ConfusionMatrixDisplay.from_predictions(y_smt,catpred)

# %%
RocCurveDisplay.from_predictions(y_smt,catpred)
